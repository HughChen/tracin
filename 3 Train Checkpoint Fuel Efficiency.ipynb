# %% [markdown]
# https://www.tensorflow.org/tutorials/keras/regression
#
# Regression example as opposed to the MNIST classification example

# %%
# Load data
from data import fuel_data
trainX, trainY, _, _ = fuel_data()

# Train and checkpoint model
from model import train_fuel, plot_loss
model, history = train_fuel(trainX, trainY)
plot_loss(history)

# %% [markdown]
# Question: if we train a model well past convergence, won't that downweight earlier epochs and upweight basically the same converged model?
